# %% [markdown]
# This code is to take the data output of a CosmicWatch as text and change it to a csv file.

# %%
import pandas as pd

fileName = 'DarkVsLight/CW_Light_2023_Jul_24'
txtName = fileName + '.txt'
csvName = fileName + '.csv'

# Read the .text file
df = pd.read_csv(txtName, sep=' ', skiprows=6, names=['Event', 'RunTime', 'ADC','SiPM','DownTime','Temp'])

# Write the .csv file
df.to_csv(csvName, index=False)

df
# Out:
#       Event  RunTime  ADC    SiPM  DownTime   Temp
# 0         1      415  679  318.29       726  22.29
# 1         2      597  261   45.09       730  22.51
# 2         3     1320   69   18.79       918  22.40
# 3         4     1783  480  130.21       922  22.51
# 4         5     1858  779  605.76       926  22.51
# ...     ...      ...  ...     ...       ...    ...
# 6236   6237  3653469  487  132.65    707116  25.63
# 6237   6238  3653854  638  261.42    707121  24.44
# 6238   6239  3654293  435  104.92    707313  25.20
# 6239   6240  3655226  226   38.63    707504  24.98
# 6240   6241  3655850  481  129.57    707509  25.20
#
# [6241 rows x 6 columns]
